# %%
import os
import pickle
import codecs
import spacy
from pattern.en import conjugate
coref_nlp = spacy.load('en_coref_md')
nlp = spacy.load('en_core_web_sm')

# %%
def coreference(text):
    pronoun = ['we all','i', 'you', 'we', 'they', 'he', 'she', 'it', 'me', 'your', 'his', 'her', 'him', 'myself', 'our', 'himself', 'ourselves','this guy']
    pronoun.sort(key=len)
    doc = coref_nlp(text)
    if doc._.has_coref:
        for coref in doc._.coref_clusters:
            main = None
            if str(coref.main).lower() in pronoun:
                for mention in coref.mentions:
                    if not str(mention).lower() in pronoun:
                        main = str(mention)
                if main == None:
                    continue
            for mention in coref.mentions:
                text = text.replace(f" {str(mention)} ",f" {str(main)}")
    return text

# %%
def transform_verb(token):
    tag = token.tag_
    res = token.text
    if tag == 'VBP' or tag == 'VB':
        res = conjugate(res, '3sg')
    return res

# %%
def transform_pronoun(speaker, text):
    if text == "You're welcome ." or text == 'Thank you .' or text == 'The pleasure is mine .':
        return text
    speakers = ["Mr.One", "Mr.Two"]
    you = speakers[(speakers.index(speaker) + 1) % 2]
    text = text.replace('don ’ t', 'do not')
    text = text.replace('your ', f"{you}'s ")
    text = text.replace('Your ', f"{you}'s ")
    text = text.replace(" ’ s ", f"'s ")
    text = text.replace(" ’ Ve ", f" have ")
    text = text.replace(" ’ re ", f" are ")
    doc = nlp(text)
    verb = None
    text_list = []
    for i in range(len(doc)):
        if verb != None:
            verb = None
            continue
        token = doc[i]
        word = str(token.text)
        index = token.i
        if word == "n't":
            word = 'not'
        if word == "'ll":
            word = 'will'
        if word == "'s" and token.pos_ == 'VERB':
            word = 'is'
        if word == "'d":
            word = token.lemma_
        if str(token.pos_) == 'PRON':
            if word.lower() == 'i' or word.lower() == 'me':
                word = f'{speaker}'
            elif word.lower() in ['we', 'us', 'our']:
                    word = f"Mr.A and Mr.B"
            elif word.lower() == 'you':
                is_you_trans = True
                try:
                    is_you_trans = not(doc[index-1].text.lower() == 'thank')
                except:
                    pass
                if is_you_trans:
                    word = f'{you}'
            elif word.lower() == 'my':
                word = f"{speaker}'s"
            elif word.lower() == 'myself':
                word = f'by {speaker}'
            elif word.lower() == 'yourself':
                word = f'by {you}'
            elif word.lower() == 'your':
                word = f"{you}'s"
            if str(token.dep_) == 'nsubj' and str(token.text.lower()) != 'we':
                if index != 0:
                    if doc[index-1].tag_ in ['VBP','VB']:
                        if not ' ' in text_list[-1]:
                            f_verb = transform_verb(doc[index-1])
                            text_list = text_list[:-1]
                            word = f_verb + ' ' + word
#                             print('before',text_list + [word])
                if index != len(doc) - 1:
                    is_question = False
                    if index != 0:
                        is_question = (str(doc[index-1].tag_)== 'MD')
                        is_question = is_question or (str(doc[index-1].text).lower() in ['does', 'is'])
                    if not is_question:
                        if doc[index+1].tag_ in ['VBP','VB']:
                            verb = transform_verb(doc[index+1])
                            word = word + ' ' + verb
                            

        text_list.append(str(word))
    res = " ".join(text_list)
    return res

# %%
def get_dialogues(lines):
    turn = 1
    dialogues = []
    texts = ""
    original_lines = lines
    for line in lines:
        line = line.strip()
        text = line[line.index(':')+2:].strip() 
        texts += text + '\n'
    coref_texts = coreference(texts)
    lines = coref_texts.strip().split('\n')
    for i in range(len(lines)):
        line = original_lines[i]
#         print(lines[i])
        speaker = line[:1]
        if speaker == 'A':
            speaker = 'Mr.One'
        if speaker == 'B':
            speaker = 'Mr.Two'
        open_paren_index = line.index('(')
        close_paren_index = line.index(')')
        act = line[open_paren_index+1:close_paren_index]
        text = transform_pronoun(speaker, lines[i])
        doc = nlp(text)
        tokens = [t.text for t in doc]
        pos = [t.pos_ for t in doc]
        tags = [t.tag_ for t in doc]
        dialogue = {
            'speaker': speaker,
            'turn': turn,
            'act': act,
            'text': tokens,
            'tags': tags,
            'pos':pos
        }
        dialogues.append(dialogue)
        turn += 1

# %%
def readfile(in_filename, inpath):
    in_filename = os.path.abspath(f"{inpath}\\{in_filename}")
    with codecs.open(in_filename, "r",'utf8') as infile:
        lines = infile.readlines()
    return lines

# %%
def writefile(out_filename, data, outpath):
    in_filename = os.path.abspath(f"{outpath}\\{out_filename}")
    with open(out_filename, 'wb') as outfile:
        pickle.dump(data,outfile)

# %%
inpath = 'corpus'
outpath = 'pos_token2'
filenames = [f for f in os.listdir(inpath) if os.path.isfile(os.path.join(inpath, f))]
# filenames
for in_filename in filenames:
    out_filename = f'{outpath}/{in_filename[:-4]}.pickle'
    lines = readfile(in_filename, inpath)
    dialogues = get_dialogues(lines)
    writefile(out_filename, dialogues, outpath)
    print(out_filename)
# Out:
# pos_token2/0.pickle
# pos_token2/1.pickle
# pos_token2/10.pickle
# pos_token2/100.pickle
# pos_token2/1000.pickle
# pos_token2/10000.pickle
# pos_token2/10001.pickle
# pos_token2/10002.pickle
# pos_token2/10003.pickle
# pos_token2/10004.pickle
# pos_token2/10005.pickle
# pos_token2/10006.pickle
# pos_token2/10007.pickle
# pos_token2/10008.pickle
# pos_token2/10009.pickle
# pos_token2/1001.pickle
# pos_token2/10010.pickle
# pos_token2/10011.pickle
# pos_token2/10012.pickle
# pos_token2/10013.pickle
# pos_token2/10014.pickle
# pos_token2/10015.pickle
# pos_token2/10016.pickle
# pos_token2/10017.pickle
# pos_token2/10018.pickle
# pos_token2/10019.pickle
# pos_token2/1002.pickle
# pos_token2/10020.pickle
# pos_token2/10021.pickle
# pos_token2/10022.pickle
# pos_token2/10023.pickle
# pos_token2/10024.pickle
# pos_token2/10025.pickle
# pos_token2/10026.pickle
# pos_token2/10027.pickle
# pos_token2/10028.pickle
# pos_token2/10029.pickle
# pos_token2/1003.pickle
# pos_token2/10030.pickle
# pos_token2/10031.pickle
# pos_token2/10032.pickle
# pos_token2/10033.pickle
# pos_token2/10034.pickle
# pos_token2/10035.pickle
# pos_token2/10036.pickle
# pos_token2/10037.pickle
# pos_token2/10038.pickle
# pos_token2/10039.pickle
# pos_token2/1004.pickle
# pos_token2/10040.pickle
# pos_token2/10041.pickle
# pos_token2/10042.pickle
# pos_token2/10043.pickle
# pos_token2/10044.pickle
# pos_token2/10045.pickle
# pos_token2/10046.pickle
# pos_token2/10047.pickle
# pos_token2/10048.pickle
# pos_token2/10049.pickle
# pos_token2/1005.pickle
# pos_token2/10050.pickle
# pos_token2/10051.pickle
# pos_token2/10052.pickle
# pos_token2/10053.pickle
# pos_token2/10054.pickle
# pos_token2/10055.pickle
# pos_token2/10056.pickle
# pos_token2/10057.pickle
# pos_token2/10058.pickle
# pos_token2/10059.pickle
# pos_token2/1006.pickle
# pos_token2/10060.pickle
# pos_token2/10061.pickle
# pos_token2/10062.pickle
# pos_token2/10063.pickle
# pos_token2/10064.pickle
# pos_token2/10065.pickle
# pos_token2/10066.pickle
# pos_token2/10067.pickle
# pos_token2/10068.pickle
# pos_token2/10069.pickle
# pos_token2/1007.pickle
# pos_token2/10070.pickle
# pos_token2/10071.pickle
# pos_token2/10072.pickle
# pos_token2/10073.pickle
# pos_token2/10074.pickle
# pos_token2/10075.pickle
# pos_token2/10076.pickle
# pos_token2/10077.pickle
# pos_token2/10078.pickle
# pos_token2/10079.pickle
# pos_token2/1008.pickle
# pos_token2/10080.pickle
# pos_token2/10081.pickle
# pos_token2/10082.pickle
# pos_token2/10083.pickle
# pos_token2/10084.pickle
# pos_token2/10085.pickle
# pos_token2/10086.pickle
# pos_token2/10087.pickle
# pos_token2/10088.pickle
# pos_token2/10089.pickle
# pos_token2/1009.pickle
# pos_token2/10090.pickle
# pos_token2/10091.pickle
# pos_token2/10092.pickle
# pos_token2/10093.pickle
# pos_token2/10094.pickle
# pos_token2/10095.pickle
# pos_token2/10096.pickle
# pos_token2/10097.pickle
# pos_token2/10098.pickle
# pos_token2/10099.pickle
# pos_token2/101.pickle
# pos_token2/1010.pickle
# pos_token2/10100.pickle
# pos_token2/10101.pickle
# pos_token2/10102.pickle
# pos_token2/10103.pickle
# pos_token2/10104.pickle
# pos_token2/10105.pickle
# pos_token2/10106.pickle
# pos_token2/10107.pickle
# pos_token2/10108.pickle
# pos_token2/10109.pickle
# pos_token2/1011.pickle
# pos_token2/10110.pickle
# pos_token2/10111.pickle
# pos_token2/10112.pickle
# pos_token2/10113.pickle
# pos_token2/10114.pickle
# pos_token2/10115.pickle
# pos_token2/10116.pickle
# pos_token2/10117.pickle
# pos_token2/10118.pickle
# pos_token2/10119.pickle
# pos_token2/1012.pickle
# pos_token2/10120.pickle
# pos_token2/10121.pickle
# pos_token2/10122.pickle
# pos_token2/10123.pickle
# pos_token2/10124.pickle
# pos_token2/10125.pickle
# pos_token2/10126.pickle
# pos_token2/10127.pickle
# pos_token2/10128.pickle
# pos_token2/10129.pickle
# pos_token2/1013.pickle
# pos_token2/10130.pickle
# pos_token2/10131.pickle
# pos_token2/10132.pickle
# pos_token2/10133.pickle
# pos_token2/10134.pickle
# pos_token2/10135.pickle
# pos_token2/10136.pickle
# pos_token2/10137.pickle
# pos_token2/10138.pickle
# pos_token2/10139.pickle
# pos_token2/1014.pickle
# pos_token2/10140.pickle
# pos_token2/10141.pickle
# pos_token2/10142.pickle
# pos_token2/10143.pickle
# pos_token2/10144.pickle
# pos_token2/10145.pickle
# pos_token2/10146.pickle
# pos_token2/10147.pickle
# pos_token2/10148.pickle
# pos_token2/10149.pickle
# pos_token2/1015.pickle
# pos_token2/10150.pickle
# pos_token2/10151.pickle
# pos_token2/10152.pickle
# pos_token2/10153.pickle
# pos_token2/10154.pickle
# pos_token2/10155.pickle
# pos_token2/10156.pickle
# pos_token2/10157.pickle
# pos_token2/10158.pickle
# pos_token2/10159.pickle
# pos_token2/1016.pickle
# pos_token2/10160.pickle
# pos_token2/10161.pickle
# pos_token2/10162.pickle
# pos_token2/10163.pickle
# pos_token2/10164.pickle
# pos_token2/10165.pickle
# pos_token2/10166.pickle
# pos_token2/10167.pickle
# pos_token2/10168.pickle
# pos_token2/10169.pickle
# pos_token2/1017.pickle
# pos_token2/10170.pickle
# pos_token2/10171.pickle
# pos_token2/10172.pickle
# pos_token2/10173.pickle
# pos_token2/10174.pickle
# pos_token2/10175.pickle
# pos_token2/10176.pickle
# pos_token2/10177.pickle
# pos_token2/10178.pickle
# pos_token2/10179.pickle
# pos_token2/1018.pickle
# pos_token2/10180.pickle
# pos_token2/10181.pickle
# pos_token2/10182.pickle
# pos_token2/10183.pickle
# pos_token2/10184.pickle
# pos_token2/10185.pickle
# pos_token2/10186.pickle
# pos_token2/10187.pickle
# pos_token2/10188.pickle
# pos_token2/10189.pickle
# pos_token2/1019.pickle
# pos_token2/10190.pickle
# pos_token2/10191.pickle
# pos_token2/10192.pickle
# pos_token2/10193.pickle
# pos_token2/10194.pickle
# pos_token2/10195.pickle
# pos_token2/10196.pickle
# pos_token2/10197.pickle
# pos_token2/10198.pickle
# pos_token2/10199.pickle
# pos_token2/102.pickle
# pos_token2/1020.pickle
# pos_token2/10200.pickle
# pos_token2/10201.pickle
# pos_token2/10202.pickle
# pos_token2/10203.pickle
# pos_token2/10204.pickle
# pos_token2/10205.pickle
# pos_token2/10206.pickle
# pos_token2/10207.pickle
# pos_token2/10208.pickle
# pos_token2/10209.pickle
# pos_token2/1021.pickle
# pos_token2/10210.pickle
# pos_token2/10211.pickle
# pos_token2/10212.pickle
# pos_token2/10213.pickle
# pos_token2/10214.pickle
# pos_token2/10215.pickle
# pos_token2/10216.pickle
# pos_token2/10217.pickle
# pos_token2/10218.pickle
# pos_token2/10219.pickle
# pos_token2/1022.pickle
# pos_token2/10220.pickle
# pos_token2/10221.pickle
# pos_token2/10222.pickle
# pos_token2/10223.pickle
# pos_token2/10224.pickle
# pos_token2/10225.pickle
# pos_token2/10226.pickle
# pos_token2/10227.pickle
# pos_token2/10228.pickle
# pos_token2/10229.pickle
# pos_token2/1023.pickle
# pos_token2/10230.pickle
# pos_token2/10231.pickle
# pos_token2/10232.pickle
# pos_token2/10233.pickle
# pos_token2/10234.pickle
# pos_token2/10235.pickle
# pos_token2/10236.pickle
# pos_token2/10237.pickle
# pos_token2/10238.pickle
# pos_token2/10239.pickle
# pos_token2/1024.pickle
# pos_token2/10240.pickle
# pos_token2/10241.pickle
# pos_token2/10242.pickle
# pos_token2/10243.pickle
# pos_token2/10244.pickle
# pos_token2/10245.pickle
# pos_token2/10246.pickle
# pos_token2/10247.pickle
# pos_token2/10248.pickle
# pos_token2/10249.pickle
# pos_token2/1025.pickle
# pos_token2/10250.pickle
# pos_token2/10251.pickle
# pos_token2/10252.pickle
# pos_token2/10253.pickle
# pos_token2/10254.pickle
# pos_token2/10255.pickle
# pos_token2/10256.pickle
# pos_token2/10257.pickle
# pos_token2/10258.pickle
# pos_token2/10259.pickle
# pos_token2/1026.pickle
# pos_token2/10260.pickle
# pos_token2/10261.pickle
# pos_token2/10262.pickle
# pos_token2/10263.pickle
# pos_token2/10264.pickle
# pos_token2/10265.pickle
# pos_token2/10266.pickle
# pos_token2/10267.pickle
# pos_token2/10268.pickle
# pos_token2/10269.pickle
# pos_token2/1027.pickle
# pos_token2/10270.pickle
# pos_token2/10271.pickle
# pos_token2/10272.pickle
# pos_token2/10273.pickle
# pos_token2/10274.pickle
# pos_token2/10275.pickle
# pos_token2/10276.pickle
# pos_token2/10277.pickle
# pos_token2/10278.pickle
# pos_token2/10279.pickle
# pos_token2/1028.pickle
# pos_token2/10280.pickle
# pos_token2/10281.pickle
# pos_token2/10282.pickle
# pos_token2/10283.pickle
# pos_token2/10284.pickle
# pos_token2/10285.pickle
# pos_token2/10286.pickle
# pos_token2/10287.pickle
# pos_token2/10288.pickle
# pos_token2/10289.pickle
# pos_token2/1029.pickle
# pos_token2/10290.pickle
# pos_token2/10291.pickle
# pos_token2/10292.pickle
# pos_token2/10293.pickle
# pos_token2/10294.pickle
# pos_token2/10295.pickle
# pos_token2/10296.pickle
# pos_token2/10297.pickle
# pos_token2/10298.pickle
# pos_token2/10299.pickle
# pos_token2/103.pickle
# pos_token2/1030.pickle
# pos_token2/10300.pickle
# pos_token2/10301.pickle
# pos_token2/10302.pickle
# pos_token2/10303.pickle
# pos_token2/10304.pickle
# pos_token2/10305.pickle
# pos_token2/10306.pickle
# pos_token2/10307.pickle
# pos_token2/10308.pickle
# pos_token2/10309.pickle
# pos_token2/1031.pickle
# pos_token2/10310.pickle
# pos_token2/10311.pickle
# pos_token2/10312.pickle
# pos_token2/10313.pickle
# pos_token2/10314.pickle
# pos_token2/10315.pickle
# pos_token2/10316.pickle
# pos_token2/10317.pickle
# pos_token2/10318.pickle
# pos_token2/10319.pickle
# pos_token2/1032.pickle
# pos_token2/10320.pickle
# pos_token2/10321.pickle
# pos_token2/10322.pickle
# pos_token2/10323.pickle
# pos_token2/10324.pickle
# pos_token2/10325.pickle
# pos_token2/10326.pickle
# pos_token2/10327.pickle
# pos_token2/10328.pickle
# pos_token2/10329.pickle
# pos_token2/1033.pickle
# pos_token2/10330.pickle
# pos_token2/10331.pickle
# pos_token2/10332.pickle
# pos_token2/10333.pickle
# pos_token2/10334.pickle
# pos_token2/10335.pickle
# pos_token2/10336.pickle
# pos_token2/10337.pickle
# pos_token2/10338.pickle
# pos_token2/10339.pickle
# pos_token2/1034.pickle
# pos_token2/10340.pickle
# pos_token2/10341.pickle
# pos_token2/10342.pickle
# pos_token2/10343.pickle
# pos_token2/10344.pickle
# pos_token2/10345.pickle
# pos_token2/10346.pickle
# pos_token2/10347.pickle
# pos_token2/10348.pickle
# pos_token2/10349.pickle
# pos_token2/1035.pickle
# pos_token2/10350.pickle
# pos_token2/10351.pickle
# pos_token2/10352.pickle
# pos_token2/10353.pickle
# pos_token2/10354.pickle
# pos_token2/10355.pickle
# pos_token2/10356.pickle
# pos_token2/10357.pickle
# pos_token2/10358.pickle
# pos_token2/10359.pickle
# pos_token2/1036.pickle
# pos_token2/10360.pickle
# pos_token2/10361.pickle
# pos_token2/10362.pickle
# pos_token2/10363.pickle
# pos_token2/10364.pickle
# pos_token2/10365.pickle
# pos_token2/10366.pickle
# pos_token2/10367.pickle
# pos_token2/10368.pickle
# pos_token2/10369.pickle
# pos_token2/1037.pickle
# pos_token2/10370.pickle
# pos_token2/10371.pickle
# pos_token2/10372.pickle
# pos_token2/10373.pickle
# pos_token2/10374.pickle
# pos_token2/10375.pickle
# pos_token2/10376.pickle
# pos_token2/10377.pickle
# pos_token2/10378.pickle
# pos_token2/10379.pickle
# pos_token2/1038.pickle
# pos_token2/10380.pickle
# pos_token2/10381.pickle
# pos_token2/10382.pickle
# pos_token2/10383.pickle
# pos_token2/10384.pickle
# pos_token2/10385.pickle
# pos_token2/10386.pickle
# pos_token2/10387.pickle
# pos_token2/10388.pickle
# pos_token2/10389.pickle
# pos_token2/1039.pickle
# pos_token2/10390.pickle
# pos_token2/10391.pickle
# pos_token2/10392.pickle
# pos_token2/10393.pickle
# pos_token2/10394.pickle
# pos_token2/10395.pickle
# pos_token2/10396.pickle
# pos_token2/10397.pickle
# pos_token2/10398.pickle
# pos_token2/10399.pickle
# pos_token2/104.pickle
# pos_token2/1040.pickle
# pos_token2/10400.pickle
# pos_token2/10401.pickle
# pos_token2/10402.pickle
# pos_token2/10403.pickle
# pos_token2/10404.pickle
# pos_token2/10405.pickle
# pos_token2/10406.pickle
# pos_token2/10407.pickle
# pos_token2/10408.pickle
# pos_token2/10409.pickle
# pos_token2/1041.pickle
# pos_token2/10410.pickle
# pos_token2/10411.pickle
# pos_token2/10412.pickle
# pos_token2/10413.pickle
# pos_token2/10414.pickle
# pos_token2/10415.pickle
# pos_token2/10416.pickle
# pos_token2/10417.pickle
# pos_token2/10418.pickle
# pos_token2/10419.pickle
# pos_token2/1042.pickle
# pos_token2/10420.pickle
# pos_token2/10421.pickle
# pos_token2/10422.pickle
# pos_token2/10423.pickle
# pos_token2/10424.pickle
# pos_token2/10425.pickle
# pos_token2/10426.pickle
# pos_token2/10427.pickle
# pos_token2/10428.pickle
# pos_token2/10429.pickle
# pos_token2/1043.pickle
# pos_token2/10430.pickle
# pos_token2/10431.pickle
# pos_token2/10432.pickle
# pos_token2/10433.pickle
# pos_token2/10434.pickle
# pos_token2/10435.pickle
# pos_token2/10436.pickle
# pos_token2/10437.pickle
# pos_token2/10438.pickle
# pos_token2/10439.pickle
# pos_token2/1044.pickle
# pos_token2/10440.pickle
# pos_token2/10441.pickle
# pos_token2/10442.pickle
# pos_token2/10443.pickle
# pos_token2/10444.pickle
# pos_token2/10445.pickle
# pos_token2/10446.pickle
# pos_token2/10447.pickle
# pos_token2/10448.pickle
# pos_token2/10449.pickle
# pos_token2/1045.pickle
# pos_token2/10450.pickle
# pos_token2/10451.pickle
# pos_token2/10452.pickle
# pos_token2/10453.pickle
# pos_token2/10454.pickle
# pos_token2/10455.pickle
# pos_token2/10456.pickle
# pos_token2/10457.pickle
# pos_token2/10458.pickle
# pos_token2/10459.pickle
# pos_token2/1046.pickle
# pos_token2/10460.pickle
# pos_token2/10461.pickle
# pos_token2/10462.pickle
# pos_token2/10463.pickle
# pos_token2/10464.pickle
# pos_token2/10465.pickle
# pos_token2/10466.pickle
# pos_token2/10467.pickle
# pos_token2/10468.pickle
# pos_token2/10469.pickle
# pos_token2/1047.pickle
# pos_token2/10470.pickle
# pos_token2/10471.pickle
# pos_token2/10472.pickle
# pos_token2/10473.pickle
# pos_token2/10474.pickle
# pos_token2/10475.pickle
# pos_token2/10476.pickle
# pos_token2/10477.pickle
# pos_token2/10478.pickle
# pos_token2/10479.pickle
# pos_token2/1048.pickle
# pos_token2/10480.pickle
# pos_token2/10481.pickle
# pos_token2/10482.pickle
# pos_token2/10483.pickle
# pos_token2/10484.pickle
# pos_token2/10485.pickle
# pos_token2/10486.pickle
# pos_token2/10487.pickle
# pos_token2/10488.pickle
# pos_token2/10489.pickle
# pos_token2/1049.pickle
# pos_token2/10490.pickle
# pos_token2/10491.pickle
# pos_token2/10492.pickle
# pos_token2/10493.pickle
# pos_token2/10494.pickle
# pos_token2/10495.pickle
# pos_token2/10496.pickle
# pos_token2/10497.pickle
# pos_token2/10498.pickle
# pos_token2/10499.pickle
# pos_token2/105.pickle
# pos_token2/1050.pickle
# pos_token2/10500.pickle
# pos_token2/10501.pickle
# pos_token2/10502.pickle
# pos_token2/10503.pickle
# pos_token2/10504.pickle
# pos_token2/10505.pickle
# pos_token2/10506.pickle
# pos_token2/10507.pickle
# pos_token2/10508.pickle
# pos_token2/10509.pickle
# pos_token2/1051.pickle
# pos_token2/10510.pickle
# pos_token2/10511.pickle
# pos_token2/10512.pickle
# pos_token2/10513.pickle
# pos_token2/10514.pickle
# pos_token2/10515.pickle
# pos_token2/10516.pickle
# pos_token2/10517.pickle
# pos_token2/10518.pickle
# pos_token2/10519.pickle
# pos_token2/1052.pickle
# pos_token2/10520.pickle
# pos_token2/10521.pickle
# pos_token2/10522.pickle
# pos_token2/10523.pickle
# pos_token2/10524.pickle
# pos_token2/10525.pickle
# pos_token2/10526.pickle
# pos_token2/10527.pickle
# pos_token2/10528.pickle
# pos_token2/10529.pickle
# pos_token2/1053.pickle
# pos_token2/10530.pickle
# pos_token2/10531.pickle
# pos_token2/10532.pickle
# pos_token2/10533.pickle
# pos_token2/10534.pickle
# pos_token2/10535.pickle
# pos_token2/10536.pickle
# pos_token2/10537.pickle
# pos_token2/10538.pickle
# pos_token2/10539.pickle
# pos_token2/1054.pickle
# pos_token2/10540.pickle
# pos_token2/10541.pickle
# pos_token2/10542.pickle
# pos_token2/10543.pickle
# pos_token2/10544.pickle
# pos_token2/10545.pickle
# pos_token2/10546.pickle
# pos_token2/10547.pickle
# pos_token2/10548.pickle
# pos_token2/10549.pickle
# pos_token2/1055.pickle
# pos_token2/10550.pickle
# pos_token2/10551.pickle
# pos_token2/10552.pickle
# pos_token2/10553.pickle
# pos_token2/10554.pickle
# pos_token2/10555.pickle
# pos_token2/10556.pickle
# pos_token2/10557.pickle
# pos_token2/10558.pickle
# pos_token2/10559.pickle
# pos_token2/1056.pickle
# pos_token2/10560.pickle
# pos_token2/10561.pickle
# pos_token2/10562.pickle
# pos_token2/10563.pickle
# pos_token2/10564.pickle
# pos_token2/10565.pickle
# pos_token2/10566.pickle
# pos_token2/10567.pickle
# pos_token2/10568.pickle
# pos_token2/10569.pickle
# pos_token2/1057.pickle
# pos_token2/10570.pickle
# pos_token2/10571.pickle
# pos_token2/10572.pickle
# pos_token2/10573.pickle
# pos_token2/10574.pickle
# pos_token2/10575.pickle
# pos_token2/10576.pickle
# pos_token2/10577.pickle
# pos_token2/10578.pickle
# pos_token2/10579.pickle
# pos_token2/1058.pickle
# pos_token2/10580.pickle
# pos_token2/10581.pickle
# pos_token2/10582.pickle
# pos_token2/10583.pickle
# pos_token2/10584.pickle
# pos_token2/10585.pickle
# pos_token2/10586.pickle
# pos_token2/10587.pickle
# pos_token2/10588.pickle
# pos_token2/10589.pickle
# pos_token2/1059.pickle
# pos_token2/10590.pickle
# pos_token2/10591.pickle
# pos_token2/10592.pickle
# pos_token2/10593.pickle
# pos_token2/10594.pickle
# pos_token2/10595.pickle
# pos_token2/10596.pickle
# pos_token2/10597.pickle
# pos_token2/10598.pickle
# pos_token2/10599.pickle
# pos_token2/106.pickle
# pos_token2/1060.pickle
# pos_token2/10600.pickle
# pos_token2/10601.pickle
# pos_token2/10602.pickle
# pos_token2/10603.pickle
# pos_token2/10604.pickle
# pos_token2/10605.pickle
# pos_token2/10606.pickle
# pos_token2/10607.pickle
# pos_token2/10608.pickle
# pos_token2/10609.pickle
# pos_token2/1061.pickle
# pos_token2/10610.pickle
# pos_token2/10611.pickle
# pos_token2/10612.pickle
# pos_token2/10613.pickle
# pos_token2/10614.pickle
# pos_token2/10615.pickle
# pos_token2/10616.pickle
# pos_token2/10617.pickle
# pos_token2/10618.pickle
# pos_token2/10619.pickle
# pos_token2/1062.pickle
# pos_token2/10620.pickle
# pos_token2/10621.pickle
# pos_token2/10622.pickle
# pos_token2/10623.pickle
# pos_token2/10624.pickle
# pos_token2/10625.pickle
# pos_token2/10626.pickle
# pos_token2/10627.pickle
